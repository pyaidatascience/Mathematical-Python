# %%
import sympy as sp

# %%
from sympy.abc import n

# %%
A = sp.Matrix([[2 ,3, 4,9], [9, 8, 3,8 ], [9, 3, 3,6]])

# %%
A
# Out:
# Matrix([
# [2, 3, 4, 9],
# [9, 8, 3, 8],
# [9, 3, 3, 6]])

# %%
A.row(0) # Slicing or popin up the elements
# Out:
# Matrix([[2, 3, 4, 9]])

# %%
A.row(1) # To pop up the second row
# Out:
# Matrix([[9, 8, 3, 8]])

# %%
A.col(2)
# Out:
# Matrix([
# [4],
# [3],
# [3]])

# %%
sp.Matrix([1, 2, 3])
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %%
sp.Matrix([1, 2, 3]).T

# %% [markdown]
# # Ploting

# %%
x = sp.symbols('x')

# %%
sp.plot(x**2+2)

# %%
sp.plot(x**2 +2, title = 'f(x) = x^2 + 2')

# %%
sp.plot((x**2 +2), (x-1), title = 'MY Graph')

# %%
sp.plot(2*x**2 + 4*x+5, title = 'f(x) = 2x^2 + 4x +5')
